# %% [markdown]
# # A Demo for splitting fragments and plotting profiles

# %% [markdown]
# #### Import the modules utils and plot from the src directory:

# %%
import src.plot as plot
import src.utils as utils

# %% [markdown]
# #### Load data from .bed and .gtf files:

# %%
GTF_FILE = "/home/stud5/testfiles/gtffiles/homo_sapiens.104.mainChr.gtf"
BED_FILE = "/home/stud5/testfiles/fragments/stomach_SM-JF1O3_rep1_fragments.bed"

# %% [markdown]
# Load Dataframe:

# %%
df = utils.get_fragment_dataframe_from_bed_file(BED_FILE)

# %% [markdown]
# Load TSS Position Set:

# %%
tss_positions = utils.get_tss_set_from_gtf_file(GTF_FILE)

# %% [markdown]
# #### Set plotting parameters:

# %%
half_window_width = 1000

# %% [markdown]
# #### Single plot for all fragment lenghts:

# %%
plot.split_and_multiplot_profile(df, tss_positions, half_window_width)

# %% [markdown]
# #### Single plot categorized into short and long fragment lengths:

# %%
split_point_1 = 150
plot.split_and_multiplot_profile(df, tss_positions, half_window_width, split_point_1)

# %% [markdown]
# #### Single plot categorized into short, long and very long fragment lengths:

# %%
split_point_1 = 150
split_point_2 = 300
plot.split_and_multiplot_profile(df, tss_positions, half_window_width, split_point_1, split_point_2)

# %% [markdown]
# #### Multiplots categorized into short and long fragment lengths:

# %%
array_of_split_points_1 = [110,130,150,170,190]
plot.split_and_multiplot_profile(df, tss_positions, half_window_width, array_of_split_points_1)

# %% [markdown]
# #### Multiplots categorized into small, long and very long fragments:

# %%
split_point_1 = 150
array_of_split_points_2 = [260,280,300,320,340]
plot.split_and_multiplot_profile(df, tss_positions, half_window_width, split_point_1, array_of_split_points_2)
